# %%
import pandas as pd
from pandas import DataFrame

import matplotlib.pyplot as plt


from sklearn.linear_model import LinearRegression

# %%
#load the dataset(clean data)
data=pd.read_csv('cost_revenue_clean.csv')

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
#define the data/predictors as the pre-set feature names
X=DataFrame(data,columns=['production_budget_usd'])

#put the target in another DataFrame
y=DataFrame(data,columns=['worldwide_gross_usd'])

# %%
plt.figure(figsize=(10,6))# figuresize--> the overall size of the chart

plt.scatter(X,y,alpha=0.3) #add transparency for the dots in the scatter plot

plt.title('Filem Cost vs Global Revenue')
plt.xlabel('production_budget_usd')
plt.ylabel('worldwide_gross_usd')

#Remove the space in the chart with defining ylim/xlim
plt.ylim(0,3000000000)
plt.xlim(0,450000000)

plt.show()

# %%
reger = LinearRegression()

# %%
reger.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# Slop Coefficient:

# %%
#theta_1
regression.coef_

# %% [markdown]
# there is a positive relationship between budget and revenue. i.e., each $ that spend on producing the movie, we should get 3$ in return

# %%
#Intercept
regression.intercept_

# %% [markdown]
# intercept --> tell us that a movie with a budget of zero, actually lose over 7million dollars

# %%
plt.figure(figsize=(10,6))# figuresize--> the overall size of the chart

plt.scatter(X,y,alpha=0.3) #add transparency for the dots in the scatter plot

#we dont want to use actual value that we have for the gross revenue(y)
#but instead we need to have the predicted value from our regressiom

plt.plot(X,regression.predict(X), color='red', linewidth=4) #plot a regression(prediction line for each X values)

plt.title('Filem Cost vs Global Revenue')
plt.xlabel('production_budget_usd')
plt.ylabel('worldwide_gross_usd')

#Remove the space in the chart with defining ylim/xlim
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show()

# %% [markdown]
# Above, we see the relationship between production_budget and revenue as predicted by our linear regression model.

# %% [markdown]
# in order to see how good is our model --> we look at R2 or Goodness of Fit

# %%
regression.score(X, y)

# %% [markdown]
# The above number is the amount of variation in film revenue that is explained by the film's budget
# i.e., our model can expalin around 55 percent of the variation that we see in the worlwide movie earnings
